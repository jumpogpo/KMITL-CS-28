# %%
import random, math
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
r = 2.0
N = 5000
d = { "Trials": [], "Pi": [] }

# %%
for i in range(1, N):
  circle_p = 0
  for x in range(i):
    x = random.uniform(-2, r)
    y = random.uniform(-2, r)

    x2 = x ** 2
    y2 = y ** 2

    if math.sqrt(x2 + y2) <= r:
      circle_p += 1
  d["Trials"].append(i)
  d["Pi"].append((circle_p / i) * 4)

# %%
df = pd.DataFrame(data = d)

# %%
df
# Out:
#       Trials        Pi
# 0          1  4.000000
# 1          2  4.000000
# 2          3  4.000000
# 3          4  2.000000
# 4          5  2.400000
# ...      ...       ...
# 4994    4995  3.151952
# 4995    4996  3.149720
# 4996    4997  3.140284
# 4997    4998  3.152461
# 4998    4999  3.147029
#
# [4999 rows x 2 columns]

# %%
plt.figure(figsize = (10,7))
plot = sns.scatterplot(x="Trials", y="Pi", s=30, marker="o", data=df)
plot.set(title='Monte Carlo Simulation to Estimate Value of Pi', xlabel="Number of Trials", ylabel="Value of Pi")
plt.axhline(y=3.14, color='r', linestyle='-')
plt.show()

# %%
sns.set_style('darkgrid')
fig = plt.figure(figsize = (10,6))
sns.histplot(df, x="Pi",color='orange');

# %%
df['Pi'].mean()
# Out:
# 3.141005414365193
